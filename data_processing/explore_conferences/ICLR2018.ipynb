# %%
import openreview, time
GUEST_CLIENT = openreview.Client(baseurl="https://api.openreview.net")

# %%
INVITATION = "ICLR.cc/2018/Conference/-/Blind_Submission"
forum_notes = list(openreview.tools.iterget_notes(GUEST_CLIENT, invitation=INVITATION))
print(len(forum_notes), "forum notes in total")
current_time = time.time()
for i, forum_note in enumerate(forum_notes):
    if i % 10 == 0:
        new_time = time.time()
        print(f"forum {i}\t{new_time - current_time:.3f} secs")
        current_time = new_time
    notes = GUEST_CLIENT.get_all_notes(forum=forum_note.id, sort='tcdate')
    for note in notes:
        # skip the forum note
        if note.id in [forum_note.id, forum_note.original]:
            continue
        
        invitation = note.invitation.split('/')[-1]
        initiators = [s.split("/")[-1] for s in note.signatures]
        assert note.referent is None
        
#         print(invitation, "\t", initiators)
#         print("\t", note.content.keys())
        
#     raise

        # add known types here
        unknown = False
        if invitation == "Official_Comment":
            if initiators[0] != "Authors" and not "Reviewer" in initiators[0] and "Chair" not in initiators[0]:
                unknown = True
        elif invitation == "Official_Review":
            if not "Reviewer" in initiators[0]:
                unknown = True
        elif "Decision" in invitation:
            if not "Chair" in initiators[0]:
                unknown = True
        elif invitation != "Public_Comment":
            unknown = True
        
        # by the end of the exploration, there should be no unknown
        if unknown:
            print(invitation, "\t", initiators)
            print("\t", note.content.keys())
            raise
# Out:
# 911 forum notes in total
# forum 0	0.001 secs
# forum 10	3.939 secs
# forum 20	3.910 secs
# forum 30	3.816 secs
# forum 40	3.779 secs
# forum 50	3.763 secs
# forum 60	3.762 secs
# forum 70	3.885 secs
# forum 80	3.790 secs
# forum 90	3.737 secs
# forum 100	3.914 secs
# forum 110	3.877 secs
# forum 120	3.846 secs
# forum 130	3.736 secs
# forum 140	3.811 secs
# forum 150	3.693 secs
# forum 160	4.004 secs
# forum 170	3.758 secs
# forum 180	3.729 secs
# forum 190	3.734 secs
# forum 200	3.848 secs
# forum 210	3.718 secs
# forum 220	3.818 secs
# forum 230	3.866 secs
# forum 240	3.816 secs
# forum 250	3.846 secs
# forum 260	3.825 secs
# forum 270	3.852 secs
# forum 280	3.750 secs
# forum 290	3.861 secs
# forum 300	3.739 secs
# forum 310	3.776 secs
# forum 320	3.752 secs
# forum 330	3.733 secs
# forum 340	3.828 secs
# forum 350	3.932 secs
# forum 360	3.919 secs
# forum 370	3.754 secs
# forum 380	3.777 secs
# forum 390	3.856 secs
# forum 400	3.791 secs
# forum 410	3.834 secs
# forum 420	3.721 secs
# forum 430	3.900 secs
# forum 440	3.840 secs
# forum 450	3.873 secs
# forum 460	3.805 secs
# forum 470	3.759 secs
# forum 480	3.888 secs
# forum 490	3.863 secs
# forum 500	3.750 secs
# forum 510	3.933 secs
# forum 520	3.741 secs
# forum 530	3.739 secs
# forum 540	3.940 secs
# forum 550	3.865 secs
# forum 560	4.075 secs
# forum 570	3.863 secs
# forum 580	3.839 secs
# forum 590	3.854 secs
# forum 600	3.782 secs
# forum 610	4.135 secs
# forum 620	3.827 secs
# forum 630	3.721 secs
# forum 640	3.786 secs
# forum 650	3.819 secs
# forum 660	3.901 secs
# forum 670	3.769 secs
# forum 680	3.755 secs
# forum 690	3.891 secs
# forum 700	3.851 secs
# forum 710	3.887 secs
# forum 720	3.723 secs
# forum 730	3.854 secs
# forum 740	3.763 secs
# forum 750	3.887 secs
# forum 760	3.835 secs
# forum 770	3.704 secs
# forum 780	3.755 secs
# forum 790	3.733 secs
# forum 800	3.765 secs
# forum 810	3.837 secs
# forum 820	3.825 secs
# forum 830	3.730 secs
# forum 840	3.806 secs
# forum 850	3.755 secs
# forum 860	3.762 secs
# forum 870	3.676 secs
# forum 880	3.745 secs
# forum 890	3.797 secs
# forum 900	3.777 secs
# forum 910	3.894 secs
