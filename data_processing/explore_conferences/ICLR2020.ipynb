# %%
import openreview, time
GUEST_CLIENT = openreview.Client(baseurl="https://api.openreview.net")

# %%
INVITATION = "ICLR.cc/2022/Conference/-/Blind_Submission"
forum_notes = list(openreview.tools.iterget_notes(GUEST_CLIENT, invitation=INVITATION))
print(len(forum_notes), "forum notes in total")
current_time = time.time()
for i, forum_note in enumerate(forum_notes):
    if i % 10 == 0:
        new_time = time.time()
        print(f"forum {i}\t{new_time - current_time:.3f} secs")
        current_time = new_time
    notes = GUEST_CLIENT.get_all_notes(forum=forum_note.id, sort='tcdate')
    for note in notes:
        # skip the forum note
        if note.id in [forum_note.id, forum_note.original]:
            continue
        
        invitation = note.invitation.split('/')[-1]
        initiators = [s.split("/")[-1] for s in note.signatures]
        assert note.referent is None

#         print(invitation, "\t", initiators)
#         print("\t", note.content.keys())
        
#     raise
    
        # add known types here
        unknown = False
        if invitation == "Official_Comment":
            if initiators[0] != "Authors" and not initiators[0].startswith("Reviewer") and "Chair" not in initiators[0]:
                unknown = True
        elif invitation == "Official_Review":
            if not initiators[0].startswith("Reviewer"):
                unknown = True
        elif invitation == "Decision":
            if not "Chair" in initiators[0]:
                unknown = True
        elif invitation != "Public_Comment":
            unknown = True
        
        # by the end of the exploration, there should be no unknown
        if unknown:
            print(invitation, "\t", initiators)
            print("\t", note.content.keys())
            raise
# Out:
# 2626 forum notes in total
# forum 0	0.001 secs
# forum 10	4.127 secs
# forum 20	4.007 secs
# forum 30	4.033 secs
# forum 40	3.985 secs
# forum 50	3.980 secs
# forum 60	3.985 secs
# forum 70	4.006 secs
# forum 80	4.020 secs
# forum 90	3.981 secs
# forum 100	3.962 secs
# forum 110	4.040 secs
# forum 120	3.965 secs
# forum 130	4.057 secs
# forum 140	4.039 secs
# forum 150	3.985 secs
# forum 160	3.994 secs
# forum 170	4.060 secs
# forum 180	3.951 secs
# forum 190	4.005 secs
# forum 200	4.009 secs
# forum 210	4.087 secs
# forum 220	4.065 secs
# forum 230	3.953 secs
# forum 240	3.995 secs
# forum 250	4.028 secs
# forum 260	3.972 secs
# forum 270	4.166 secs
# forum 280	4.057 secs
# forum 290	4.047 secs
# forum 300	4.075 secs
# forum 310	4.095 secs
# forum 320	3.921 secs
# forum 330	3.915 secs
# forum 340	4.247 secs
# forum 350	4.060 secs
# forum 360	4.052 secs
# forum 370	3.964 secs
# forum 380	4.074 secs
# forum 390	3.930 secs
# forum 400	4.390 secs
# forum 410	4.105 secs
# forum 420	4.136 secs
# forum 430	3.952 secs
# forum 440	3.972 secs
# forum 450	4.027 secs
# forum 460	4.000 secs
# forum 470	4.004 secs
# forum 480	3.954 secs
# forum 490	4.043 secs
# forum 500	3.927 secs
# forum 510	3.899 secs
# forum 520	4.026 secs
# forum 530	3.932 secs
# forum 540	4.003 secs
# forum 550	4.122 secs
# forum 560	3.892 secs
